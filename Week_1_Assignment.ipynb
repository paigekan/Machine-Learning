# %% [markdown]
# Step 1: Import Packages

# %%
import pandas as pd
from google.colab import drive
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Step 2: Connect to Google Drive

# %%
drive.mount('/content/gdrive/', force_remount = True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# Step 3: Read File

# %%
df = pd.read_csv("/content/gdrive/MyDrive/Econ441B/CarPrice.csv")

# %% [markdown]
# Step 4: Data Cleaning and Visualization

# %%
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
plt.figure(figsize = (10,5))
plt.title("Histogram of Highway MPG")
sns.histplot(df.highwaympg, stat = 'density')
sns.kdeplot(df.highwaympg, color = 'red')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# Highway MPG appears to approximately follow a normal distribution.
